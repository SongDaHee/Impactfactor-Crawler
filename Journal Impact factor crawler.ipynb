# %%
from urllib.parse import urlencode, quote_plus
import requests
from urllib.parse import urlparse
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import re

f=open('C:\\Users\\Song\\Desktop\\Crawler2\\list_input.txt','r')
lines=f.readlines()
file=open('list_output4.txt','w',encoding='utf-8')
t=0
for line in lines:
    scholar=line
    jyear=1
    jname='a'
    sssoup='find'
    impactfactor='0'
    t=t+1
    if(t%3==0):
        time.sleep(4)
        
    # riss  
    try:
    
        options=webdriver.ChromeOptions()
        options.add_argument('headless')
        options.add_argument('window-size=1920x1080')
        options.add_argument("disable-gpu")
        options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")
        
        driver=webdriver.Chrome('/Users/song/Downloads/chromedriver',chrome_options=options)
        driver.implicitly_wait(3)
        url2='http://www.riss.kr/index.do'
        driver.get(url2)   

        driver.find_element_by_xpath('//*[@id="normal"]/fieldset/div[2]/p/label[3]').click()        
        driver.find_element_by_xpath('//*[@id="basicQuery"]').click()
        for s in scholar:
            driver.find_element_by_xpath('//*[@id="basicQuery"]').send_keys(s)
            time.sleep(0.1)
            
        try:
            driver.find_element_by_xpath('//*[@id="normal"]/fieldset/div[1]/input[2]').click()
        except:
            pass

        if(t%5==0):
            time.sleep(2)
        
        time.sleep(3)
        source_r=driver.page_source
        soup_r=BeautifulSoup(source_r,'html.parser')

        soups_r=soup_r.find("p",class_="txt")
        soups_r2=soups_r.find("a")
        soups_r9=soups_r2.text
        soups_r3=soups_r2.get("href")
        urlr='http://www.riss.kr'+soups_r3
        
        #jyear 찾기
        soups_r4=driver.find_element_by_xpath('//*[@id="level4_mainContent"]/form/div[3]/div[2]/div/div[2]/ul/li/div[1]/span[2]')
        soups_r5=soups_r4.text
        soups_r10=soups_r5.split(',')
        soups_r11=soups_r10[-1]
        soups_r6=int(re.findall('\d+',soups_r11)[0])
        
        driver.quit()
        
        options=webdriver.ChromeOptions()
        options.add_argument('headless')
        options.add_argument('window-size=1920x1080')
        options.add_argument("disable-gpu")
        options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")

        
        driver=webdriver.Chrome('/Users/song/Downloads/chromedriver',chrome_options=options)        
        driver.implicitly_wait(3)
        driver.get(urlr)

        #jname 찾기
        soups_r7=driver.find_element_by_xpath('//*[@id="level4_mainContent"]/div/div[3]/ul/li[3]/p/a')
        soups_r8=soups_r7.text
        
        if jname=='a':
            jname=soups_r8
            sssoup=soups_r9
            #print("jname=",jname)
            
        if jyear==1:
            jyear=soups_r6
            #print("jyear=",jyear)
        
    except:
        pass
    
    driver.quit()

    
    #google scholar
    if jname=='a' and jyear==1:
        try:
            
            options=webdriver.ChromeOptions()
            options.add_argument('headless')
            options.add_argument('window-size=1920x1080')
            options.add_argument("disable-gpu")
            options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")
            
            driver=webdriver.Chrome('/Users/song/Downloads/chromedriver',chrome_options=options)
            driver.implicitly_wait(3)

            if(t%4==0):
                time.sleep(4)
            url='https://scholar.google.co.kr/'
            driver.get(url)

            if(t%3==0):
                time.sleep(4)
            if(t%7==0):
                time.sleep(2)
            
            for s in scholar:
                driver.find_element_by_xpath('//*[@id="gs_hdr_tsi"]').send_keys(s)
                time.sleep(0.5)

            driver.implicitly_wait(3)
            driver.find_element_by_xpath('//*[@id="gs_hdr_tsb"]').click()
            if(t%7==0):
                time.sleep(2)
            
            source=driver.page_source
            soup=BeautifulSoup(source,'html.parser')
            ssoup=soup.find("h3",class_="gs_rt")

            sssoup=ssoup.text


            if(len(scholar)>len(sssoup)):
                l=len(scholar)-len(sssoup)
            else:
                l=len(sssoup)-len(scholar)

            #scholar jname, jyear 찾기

            soups=soup.find("div",class_="gs_a")
            soups2=soups.text.split("-")
            soups3=soups2[1]
            soups4=soups3.split(",")

            if len(soups4)==2:
                if (len(soups4[1].strip())<5) and (l<10):
                    jname=soups4[0].strip('…').strip()
                    jyear=soups4[1].strip()
                    #print("jname=",jname)
                    #print("jyear=",jyear)
                else:
                    jname=soups4[0].strip('…').strip()+' '+soups4[1].strip()

            soups5=soup.find("a",class_="gs_or_nvi")
            soups6=soups5.get("href")
            urls=soups6

        except:
            pass
        
        driver.quit()
    
    #scholar2
        try:
            options=webdriver.ChromeOptions()
            options.add_argument('headless')
            options.add_argument('window-size=1920x1080')
            options.add_argument("disable-gpu")
            options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")

            driver=webdriver.Chrome('/Users/song/Downloads/chromedriver',chrome_options=options)
            driver.implicitly_wait(3)
            if(t%8==0):
                time.sleep(3)
            driver.get(urls)
            
            jname2=driver.find_element_by_xpath('/html/body/div[2]/font[2]/span/div/nobr')
            jname2=jname2.text
            if len(jname2)>len(jname):
                jname=jname2
                #print("jname=",jname)
                #print("jyear=",jyear)

        except:
            pass

        driver.quit()
   
    #JCR
    options=webdriver.ChromeOptions()
    options.add_argument('headless')
    options.add_argument('window-size=1920x1080')
    options.add_argument("disable-gpu")
    options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")

    driver=webdriver.Chrome('/Users/song/Downloads/chromedriver',chrome_options=options)
    driver.implicitly_wait(3)

    url3='https://jcr.incites.thomsonreuters.com/JCRJournalHomeAction.action'
    driver.get(url3)

    time.sleep(3)


    driver.find_element_by_xpath('//*[@id="skip-to-content"]/div/div[2]/div[1]/div[1]/div[4]/i').click()

    for j in jname:
        driver.find_element_by_xpath('//*[@id="journalSearch-inputEl"]').send_keys(j)
        time.sleep(0.1)

    time.sleep(2)
    driver.find_element_by_xpath('//*[@id="journalSearch-inputEl"]').send_keys(Keys.ENTER)

    driver.find_element_by_xpath('//*[@id="ext-gen1097"]').click()

    source_new=driver.page_source
    soup_new=BeautifulSoup(source_new,'html.parser')
    soups_new=soup_new.find_all("li",class_='x-boundlist-item')

    s_list=[]

    for s in soups_new:
        s_list.append(s.text)
        
    jyear=str(jyear)
    
    for i in s_list:
        if i==jyear:
            jye=2017-int(i)
            jy=str(jye)
            driver.find_element_by_xpath('//*[@id="boundlist-1171-listEl"]/ul/li[' +jy+ ']').click()
            driver.find_element_by_xpath('//*[@id="skip-to-content"]/div/div[2]/div[1]/div[9]/div[3]/a[2]').click()
    
    time.sleep(2)        
    source_j=driver.page_source
    soup_j=BeautifulSoup(source_j,'html.parser')
    soups_j=soup_j.find_all("div",class_='x-grid-cell-inner')
    
    jname=jname.upper()

    j_list=[]
    
    for j in soups_j:
        j_list.append(j.text)

    try:
        if jname==j_list[2]:
            impactfactor=j_list[6]
        else:
            impactfactor='0'
            
    except:
        pass
    
    driver.quit()
    
    #web of science
    if impactfactor=='0':
        try:
            
            options=webdriver.ChromeOptions()
            options.add_argument('headless')
            options.add_argument('window-size=1920x1080')
            options.add_argument("disable-gpu")
            options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")
            
            driver=webdriver.Chrome('/Users/song/Downloads/chromedriver',chrome_options=options)
            driver.implicitly_wait(3)
            
            url4='http://apps.webofknowledge.com/WOS_GeneralSearch_input.do?product=WOS&search_mode=GeneralSearch&SID=E2sQzu6vkqLlwp8pcR3&preferencesSaved='
            driver.get(url4)

            time.sleep(3)
            
            driver.find_element_by_xpath('//*[@id="clearIcon1"]').click()
            
            time.sleep(3)
            
            for w in scholar:
                driver.find_element_by_xpath('//*[@id="value(input1)"]').send_keys(w)
                time.sleep(0.1)

            try:
                driver.find_element_by_xpath('//*[@id="searchCell1"]/span[1]/button').click()
            except:
                pass
                
            time.sleep(5)
            
            source_w=driver.page_source
            soup_w=BeautifulSoup(source_w,'html.parser')
            
            soups_w4=soup_w.find("a",class_="smallV110")
            
            driver.find_element_by_xpath('//*[@id="show_journal_overlay_link_1"]/a/span/value').click()
            time.sleep(3)
            source_w=driver.page_source
            soup_w=BeautifulSoup(source_w,'html.parser')
            soups_w=soup_w.find("table",class_='Impact_Factor_table')
            soups_w3=soups_w.find("tr")
            soups_w2=soup_w.find("span",class_='sourceTitle_txt')
            
            if len(scholar)>len(soups_w4.text):
                l=len(scholar)-len(soups_w4.text)
            else:
                l=len(soups_w4.text)-len(scholar)
            
            if l<10:
                sssoup=soups_w4.text
                jname=soups_w2.text
                impactfactor=soups_w3.text.strip()
            
        except:
            pass
        
        driver.quit()
        
    print("find=",sssoup)
    print("scholar=",scholar)
    print("jname=",jname)
    print("jyear=",jyear)
    print("impactfactor=",impactfactor)

    jyear=str(jyear)
    impactfactor=str(impactfactor)
    file.write(scholar)
    file.write(sssoup+'\n')
    file.write('jname='+jname+'\n')
    file.write('jyear='+jyear+'\n')
    file.write('impactfactor='+impactfactor+'\n\n')

    
file.close()  
f.close()
# Out:
# find= Adaptive Multi-Module Approximation Network
# scholar= Adaptive multi-module approximation network
#
# jname= INTELLIGENT ENGINEERING SYSTEMS THROUGH ARTIFICIAL NEURAL NETWORKS
# jyear= 1997
# impactfactor= 0
# find= Fuzzy Adaptive Multi-module Approximation Network
# scholar= Fuzzy adaptive multi-module approximation network
#
# jname= INTERNATIONAL CONFERENCE- NORTH AMERICAN FUZZY INFORMATION PROCESSING SOCIETY
# jyear= 1999
# impactfactor= 0
# find= [인용][C] Decision making using Topological Information
# scholar= Decision making using Topological Information, Processing
#
# jname= 7TH WORLD MULTICONFERENCE ON SYSTEMICS CYBERNETICS …
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Host-based Intrusion Detection System using Optimal Representation, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Macroscopic E-mail Virus Detection using Neural Network, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Role-based Access Control using Neural Network, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= A New Method to Decide Easy and Hard-to- Guess Passwords for Proactive Password Checking, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Neural Network Based Proactive Password Checking using Linguistic Information, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find=
#
# Reorganizing news web pages for mobile users
#
#
# scholar= Reorganizing news pages for mobile users
#
# jname=
#
# Lecture Notes in Artificial Intelligence
#
#
# jyear= 2003
# impactfactor= 0.302
# find= find
# scholar= Concept Hierarchy based Text Segmentation, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Refining term weights of Document, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Matchmaking buyer and seller model for E-Commerce, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= Sports Image Classification through Bayesian Classifier
# scholar= Sports image classification through Bayesian classifier
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= ASPerson: Agent System for Personalizing Web Contents over Wireless Connection
# scholar= Agent system for personalizing Web contents over wireless connection
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Web Security Using Distributed Role Hierarchy
# scholar= Web Security using Distributed Role Hierarchy
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Performance Improvement of Information Service Using Priority Driven Method
# scholar= Performance Improvement of Information Service Using Priority Driven Method
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Autonomic Protection System Using Adaptive Security Policy
# scholar= Autonomic protection system using adaptive security policy
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= A Novel Method to Support User's Consent in Usage Control for Stable Trust in E-business
# scholar= A novel method to support user's consent in usage control for stable trust in e-Business
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Intrusion Detection Based on Feature Transform Using Neural Network
# scholar= Intrusion Detection Based on Feature Transform using Neural Network
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Artificial Immune System against Viral Attack
# scholar= Artificial Immune System against Viral Attack
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Effective Detector Set Generation and Evolution for Artificial Immune System
# scholar= Effective detector set generation and evolution for artificial immune system
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Effective Web-Related Resource Security Using Distributed Role Hierarchy
# scholar= Effective Web-related Resource Security using Distributed Role Hierarchy
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Efficient Role Based Access Control Method in Wireless Environment
# scholar= Efficient Role Based Access Control Method in Wireless Environment
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= find
# scholar= Supply Chain Management using Cooperative Multi-Agent Model
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= Biologically Inspired Computer Virus Detection System
# scholar= Biologically Inspired Computer Virus Detection System
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= A Novel Hybrid Approach of Mean Field Annealing and Genetic Algorithm for Load Balancing Problem
# scholar= A novel hybrid approach of mean field annealing and genetic algorithm for load balancing problem
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= A Novel Approach to Function Approximation: Adaptive Multimodule Regression Networks
# scholar= Novel approach to function approximation: Adaptive multimodule regression networks
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= A Novel Approach to Load Balancing Problem
# scholar= A Novel Approach to Load Balancing Problem
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Asynchronous Distributed Genetic Algorithm for Optimal Channel Routing
# scholar= Asynchronous Distributed Genetic Algorithm for Optimal Channel Routing
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= A Novel Approach for Simplifying Neural Networks by Identifying Decoupling Inputs
# scholar= A Novel Approach for Simplifying Neural Networks by Identifying Decoupling Inputs
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= The Analysis of Hardware Supported Cache Lock Mechanism Without Retry
# scholar= The Analysis of Hardware Supported Cache Lock Mechanism without Retry
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Distributed Channel Routing Using Genetic Algorithm
# scholar= Distributed Channel Routing using Genetic Algorithm
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= Distributed Simulated Annealing for Composite Stock Cutting Problem
# scholar= Distributed Simulated Annealing for Composite Stock Cutting Problem
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2004
# impactfactor= 0.513
# find= find
# scholar= 공동 구매를 위한 사용자 프로파일 기반의 주문 통합 방법
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Neural Network based Extend RBAC System for Large Scale Organizations, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Cooperation Model for Supply Chain Management using Multi-Agent System, Processing
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= Multi Class Adult Image Classification Using Neural Networks
# scholar= Multi Class Adult Image Classification using Neural Networks
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2005
# impactfactor= 0.402
# find= find
# scholar= Effective User Interface for DIgital Video Library
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= Detecting Adult Images Using Seven MPEG-7 Visual Descriptors
# scholar= Detecting Adult Images using Seven MPEG-7 Visual Descriptors
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2005
# impactfactor= 0.402
# find= Neural Network Based Adult Image Classification
# scholar= Neural network based adult image classification
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2005
# impactfactor= 0.402
# find= Effective Information Sharing Using Concept Mapping
# scholar= Effective Information Sharing using Concept Mapping
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2005
# impactfactor= 0.402
# find= find
# scholar= Combination of Learning Contents and Technology
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= E-mail Worm Detection Using the Analysis of Behavior
# scholar= Worm Detection using the Analysis of Behavior
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2005
# impactfactor= 0.402
# find= An Effective Method for Location Privacy in Ubiquitous Computing
# scholar= An effective method for location privacy in ubiquitous computing
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2005
# impactfactor= 0.402
# find= find
# scholar= an expeditious approach to diminish SPAM
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Resource Allocation in Multi-agent System for Ubiquitous Computing Service
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= Role-Based Access Control Model for Ubiquitous Computing Environment
# scholar= Role-based Access Control Model for Ubiquitous Environment
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2006
# impactfactor= 0
# find= find
# scholar= Personalization of Digital Contents, Int'l Journal of Contents
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Ubiquitous role-based access control model, IEICE Transactions on Fundamentals of Electronics
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= E-Consumer Behaviour: Past, Present and Future Trajectories of an Evolving Retail Revolution
# scholar= Present and Future of E-Business
#
# jname= INTERNATIONAL JOURNAL OF E BUSINESS RESEARCH
# jyear= 2008
# impactfactor= 0
# find=
#
# Multi-module image classification system
#
#
# scholar= Multi-Module Image Classification System
#
# jname=
#
# Lecture Notes in Computer Science
#
#
# jyear= 2006
# impactfactor= 0.402
# find= Image Identification System Using MPEG-7 Descriptors
# scholar= Image Identification System using MPEG-7 Descriptors
#
# jname= LECTURE NOTES IN CONTROL AND INFORMATION SCIENCES
# jyear= 2006
# impactfactor= 0
# find= A Novel Approach in Sports Image Classification
# scholar= A Novel Approach in Sports Image Classification
#
# jname= LECTURE NOTES IN CONTROL AND INFORMATION SCIENCES
# jyear= 2006
# impactfactor= 0
# find= Hierarchical Adult Image Rating System
# scholar= Hierarchical Adult Image Rating System
#
# jname= LECTURE NOTES IN CONTROL AND INFORMATION SCIENCES
# jyear= 2006
# impactfactor= 0
# find=
#
# Personalized digital E-library service using users' profile information
#
#
# scholar= Personalized Digital E-library Service Using Users' Profile Information
#
# jname=
#
# LECTURE NOTES IN COMPUTER SCIENCE
#
#
# jyear= 2006
# impactfactor= 0.402
# find= Personalized Content Presentation for Virtual Gallery
# scholar= Personalized Content Presentation for Virtual Gallery
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2006
# impactfactor= 0
# find= find
# scholar= The Concept and Application Methods of Intelligent Content
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Artificial Intelligence Techniques in Game Contents
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Relationship-Based Access Control Model
#
# jname= A
# jyear= 1
# impactfactor= 0
# find=
# Affective content analysis of music emotion through EEG
#
# scholar= Feature Transformation based Music Retrieval System
#
# jname=
#
# MACHINE VISION AND APPLICATIONS
#
#
# jyear= 1
# impactfactor= 2.005   2.065
# find= Browsing Personal Images Using Episodic Memory (Time + Location)
# scholar= Database using Personal Information Management System
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2006
# impactfactor= 0
# find= find
# scholar= 주가지수 관계와 유전자 알고리즘을 이용한 주식예측
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 다중 감정 에이전트를 이용한 자동 이야기 생성 시스템의 설계
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 감정 에이전트를 이용한 자동 이야기 생성 시스템의 설계
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 사용자의 감정을 표현하는 소형 로봇
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 지능을 이용한 가상대학 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 실시간 상호작용 동영상 콘텐츠 LMS/LCMS 개발 (분석,설계 중심으로)
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 저탄소 정책을 위한 배출량측정 그린IT융합시스템에 관한 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 인터넷 정보기술을 활용한 서비스 사업 접목방안에 관한 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 저탄소 녹색산업을 위한 스마트 팜 시스템에 관한 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 시간적 데이터와 공간적 데이터의 문맥적 융합 접근방법에 관한 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 제한적 인지 데이터에 기초한 에이전트 움직임-데이터 궤적의 인간다움
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= SCORM 표준 확장을 이용한 실시간 멀티미디어 e-Learning 시스템 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= SNS를 이용한 소셜 시나리오 생성에 관한 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= an automatic program for clustering orthologs flexibly combining a Recursive and a Markov clustering algorithms
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 마스터 테이블을 이용한 SaaS방식의 소프트웨어 제공 모델
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 실시간으로 학습자 수준에 적합한 문제를 제공하는 e-Learning 시스템
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 사용자 수준에 따라 실시간으로 난이도가 적용되는 스포츠게임
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= IGC: An Image Genre Classification System
# scholar= IGC: An Image Genre Classification System
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2011
# impactfactor= 0
# find= A Cartoon Image Classification System Using MPEG-7 Descriptors
# scholar= A Cartoon Image Classification System Using MPEG-7 Descriptors
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2011
# impactfactor= 0
# find= Development of LMS/LCMS (Contents Link Module) Real-Time Interactive in Videos for Maximizing the Effect of Learning
# scholar= Development of LMS/LCMS (Contents Link Module) Real-time Interactive in Videos for Maximizing the Effect of Learning
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 2011
# impactfactor= 0
# find= Development of Real-Time Learning Components Using Expanded SCORM
# scholar= Development of Real-time Learning Components using Expanded SCORM
#
# jname= COMMUNICATIONS IN COMPUTER AND INFORMATION SCIENCE
# jyear= 2011
# impactfactor= 0
# find= find
# scholar= 검색의도 파악을 위한 질의어 관계유형에 관한 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 목적 지향적 학습을 이용한 적응적 전술 생성 시스템 설계
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 사례기반 추론을 이용한 실시간 전술 생성 시스템 설계
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= A DICOM Compliant Virtual Collaborative System in Ubiquitous Environments
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Characteristics of Virtual Humans with Limited Perception-based Mapping in coping with Contingent Situations
#
# jname= A
# jyear= 1
# impactfactor= 0
# find=
#
# A Distributed Hybrid Algorithm for Composite Stock Cutting
#
#
# scholar= A Distributed Hybrid Algorithm for Composite Stock Cutting
#
# jname=
#
# APPLIED MATHEMATICS & INFORMATION SCIENCES
#
#
# jyear= 1
# impactfactor= 1.232   1.204
# find= find
# scholar= Image Classification using Adaptive Multi-Module
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Increasing Search Success rate by Comparing Queries Formation Patterns
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Personalized Interactive e-Learning System using Expanded SCORM
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 효율적 검색의도 파악을 위한 쿼리 단어 가시화에 관한 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Video stabilization by detecting intentional and unintentional camera motions
#
# jname= A
# jyear= 1
# impactfactor= 0
# find=
#
# Automated Selection of Appropriate Advertisements for Digital Signage by analyzing Crowd Demographics
#
#
# scholar= Automated Selection of Appropriate  Advertisements for Digital Signage by Analyzing Crowd Demographics
#
# jname=
#
# INFORMATION-AN INTERNATIONAL INTERDISCIPLINARY JOURNAL
#
#
# jyear= 1
# impactfactor= 0.358   0.269
# find=
#
# A Distributed Hybrid Algorithm for Composite Stock Cutting
#
#
# scholar= A Distributed Hybrid Algorithm for Composite Stock Cutting
#
# jname=
#
# APPLIED MATHEMATICS & INFORMATION SCIENCES
#
#
# jyear= 1
# impactfactor= 1.232   1.204
# find= find
# scholar= A Digital Imaging and Communications in Medicine Compliant Virtual Collaborative System in Ubiquitous Environments
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Characteristics of Virtual Humans with Limited Perception-based Mapping in coping with Contingent Situations
#
# jname= A
# jyear= 1
# impactfactor= 0
# find=
#
# An innovative method for data and software integration in SaaS
#
#
# scholar= An innovative method for data and software integration in SaaS
#
# jname=
#
# COMPUTERS & MATHEMATICS WITH APPLICATIONS
#
#
# jyear= 1
# impactfactor= 1.531   2.008
# find= find
# scholar= Storyline generation system using situation cases
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= A Functional Test Bed for Producing Virtual Human's Human-Like Movement Based on Limited Perception
# scholar= A functional test bed for producing virtual human's human-like movement based on limited perception
#
# jname= APPLIED MECHANICS AND MATERIALS
# jyear= 2013
# impactfactor= 0
# find= find
# scholar= On the Effect of Image Filtering in the Process of MPEG7 Visual Descriptor
#
# jname= A
# jyear= 1
# impactfactor= 0
# find=
#
# An approach to mitigate DoS attack based on routing misbehavior in wireless ad hoc networks
#
#
# scholar= An approach to mitigate DoS attack based on routing misbehavior in wireless ad hoc networks
#
# jname=
#
# PEER-TO-PEER NETWORKING AND APPLICATIONS
#
#
# jyear= 2015
# impactfactor= 1.262   1.093
# find= find
# scholar= e-Learning System That Provides Personalized Adaptive Contents in Real-Time
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Increasing Search Success rate by Comparing Queries Formation Patterns
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Personalized Interactive e-Learning System using Expanded SCORM
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= A Distributed Channel Routing using Mean Field Genetic Algorithm
#
# jname= A
# jyear= 1
# impactfactor= 0
# find=
# Evolutionary Fuzzy Relational Modeling for Fuzzy Time Series Forecasting
#
#
# scholar= Stock Forecasting using Stock Index Relation and Genetic Algorithm
#
# jname=
#
# APPLIED INTELLIGENCE
#
#
# jyear= 1
# impactfactor= 1.904   1.804
# find= find
# scholar= A Story Generation System Based on Emotional Agent
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= A Situation-based Storyline Generation System
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Search (Model)
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Spatial & Temporal Convergence
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= CO2 simulator
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Flock Movement
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= Distributed Cooperation in the Absence of Communication
# scholar= Distributed Cooperation
#
# jname= PROCEEDINGS OF THE ANNUAL ACM SYMPOSIUM ON PRINCIPLES OF DISTRIBUTED COMPUTING
# jyear= 2000
# impactfactor= 0
# find= find
# scholar= Convergence Error Detection
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= Search (Extraction)
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= AVATAR: An Intelligent Air Traffic Control Simulator and Trainer
# scholar= Intelligent Traffic Simulator
#
# jname= LECTURE NOTES IN COMPUTER SCIENCE
# jyear= 1998
# impactfactor= 0
# find= Multi-model Fusion Modeling Algorithms for Fermentation Process
# scholar= Ferment Algorithms
#
# jname= INFORMATION AND CONTROL -SHENYANG-
# jyear= 2005
# impactfactor= 0
# find= find
# scholar= Building Automation System
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= Convergence: The Arts and Technology, A new Variation of an Ancient Dance
# scholar= Art and Technology Convergence
#
# jname= BIENNIAL SYMPOSIUM FOR ARTS AND TECHNOLOGY
# jyear= 1995
# impactfactor= 0
# find= Cancer Therapy: Smart Probe for Tracing Cancer Therapy: Selective Cancer Cell Detection, Image-Guided Ablation, and Prediction of Therapeutic Response In Situ (Small 36/2015)
# scholar= Selective Image Tracing
#
# jname= SMALL
# jyear= 2015
# impactfactor= 0
# find= find
# scholar= 감정데이터베이스 기반 소셜 미디어 마이닝 시스템 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 행렬분해모델과 군집화를 이용한 영상 추천 방법 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
# find= find
# scholar= 대화텍스트 내 핵심 감정 추출을 위한 감정 간 연관 관계 연구
#
# jname= A
# jyear= 1
# impactfactor= 0
